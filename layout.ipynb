# %%
import pandas as pd
import numpy as np
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
from pdfquery import PDFQuery

# %%
import fitz

# %%
doc = fitz.open("Layout.pdf")

# %%
for page in doc:
    text = page.get_text()
    print(text)
# Out:
# E1
# +30.86 NVP
# P.S1.1.01 (600x 1030)
# P.S1.1.02 (600x 1030)
# E1
# +30.86 NVP
# P.S1.2 (600x 800)
# P.S1.13 (700x 850)
# 10
# -
# 4
# -
# 3
# -
# 1
# -
# 2
# -
# 8
# -
# 9
# -
# E1
# +30.86 NVP
# P.S1.1.07 (600x 800)
# P.S1.1.08 (600x 800)
# 5
# -
# 6
# -
# 7
# -
# 11
# -
# 12
# -
# P.S1.1.01 (800x 600)
# V.S2.S01
# C.S2.21
# (700x 700)
# P.S1.13 (700x 850)
# P.S1.13 (700x 850)
# P.S1.10.2 (900x 850)
# V.S1.S01
# P.S1.1.07 (600x 800)
# C.S2.22
# (700x 700)
# E1
# SSL +30.86
# C.S2.26
# (900x 900)
# C.S2.27
# (900x 900)
# P.S1.14 (700x 850)
# P.S1.13 (700x 850)
# E1
# SSL +30.86
# E1
# SSL +30.86
# E1
# SSL +30.86
# E1
# SSL +30.89
# E1
# SSL +30.86
# E1
# SSL +30.89
# PLAN DE REPERAGE :
# Nord
# Bonnes conditions - Tous les éléments sauf ferraillage supérieur des dalles et des poutres
#                                              d'épaisseur de plus de 25 cm
# Barre
# ø (mm)
# Diamètre de Mandrin
# C35/45
# Ancrage (mm)
# Recouvrement (mm)
# C45/55
# Ancrage (mm)
# Recouvrement (mm)
# C60/75
# Ancrage (mm)
# Recouvrement (mm)
# C80/95
# Ancrage (mm)
# Recouvrement (mm)
# 8
# 32
# 181
# 271
# 153
# 229
# 133
# 200
# 133
# 200
# 40
# 226
# 339
# 191
# 287
# 166
# 250
# 166
# 250
# 48
# 300
# 450
# 254
# 381
# 221
# 332
# 221
# 332
# 64
# 448
# 673
# 379
# 569
# 331
# 496
# 331
# 496
# 597
# 895
# 505
# 757
# 440
# 660
# 440
# 660
# 782
# 662
# 993
# 577
# 865
# 577
# 865
# 873
# 761
# 761
# 10
# 12
# 16
# 20
# 25
# 32
# 140
# 175
# 1174
# 224
# 1032
# 1549
# 1310
# 1142
# 1142
# Mauvaises conditions -
# Ferraillage supérieur des dalles et des poutres d'épaisseur de plus de 25 cm
# Barre
# ø (mm)
# Diamètre de Mandrin
# C35/45
# Ancrage (mm)
# Recouvrement (mm)
# C45/55
# Ancrage (mm)
# Recouvrement (mm)
# C60/75
# Ancrage (mm)
# Recouvrement (mm)
# C80/95
# Ancrage (mm)
# Recouvrement (mm)
# 8
# 32
# 258
# 387
# 218
# 327
# 190
# 285
# 40
# 323
# 484
# 273
# 409
# 238
# 357
# 48
# 429
# 643
# 363
# 544
# 316
# 474
# 64
# 641
# 961
# 542
# 813
# 472
# 708
# 853
# 721
# 629
# 943
# 945
# 824
# 10
# 12
# 16
# 20
# 25
# 32
# 140
# 175
# 1677
# 224
# 1475
# 2212
# 1871
# 1631
# *Note : Ces valeurs sont à considérer sauf indication contraire
# 1279
# 1082
# 1118
# 1418
# 1236
# 1247
# 1087
# 190
# 285
# 238
# 357
# 316
# 474
# 472
# 708
# 629
# 943
# 824
# 1631
# 1236
# 1087
# 56
# 374
# 561
# 317
# 475
# 276
# 414
# 276
# 414
# 14
# 56
# 535
# 802
# 452
# 678
# 394
# 591
# 14
# 394
# 591
# 1186
# 1034
# 40
# 280
# 1403
# 2104
# 1780
# 1551
# 40
# 280
# 2004
# 3006
# 2542
# 1695
# 2216
# 1477
# 1034
# 1551
# 2216
# 1477
# Elément structurel
# Barrettes de fondation
# Paroi moulée
# Radier
# Contre voile**
# Voiles principaux du noyau(≥300mm)et
# Poteaux principaux de la tour
# Poteaux extérieurs
# Poutres
# Planchers béton
# Chape de compression des DAP
# Escalier préfabriqué
# Rampe accès parking et sa toiture
# accessible aux pompier
# Dalles et poutres des terrasses sous
# étanchéité
# Radier et toiture du Carneau
# Classe de
#    béton
# C40/50
# C40/50
# C45/55
# C45/55
# C60/75
# C45/55
# C80/95
# C80/95
# C35/45
# C35/45
# C35/45
# C35/45
# C45/55
# C35/45
# C35/45
# Enrobage
#      mm
# 75
# 75
# 50
# 55
# 55/30
# 55/30
# 60
# 60
# *
# 20
# 35
# 35
# 35
# 35
# * Selon l'étage. Voir indication sur le plan
# rampe voiture intérieure
# 35
# C35/45
# ascenseur panoramique y compris
# linteaux: C60**
# Voiles secondaires du noyau(<300mm)et
# Autres voiles coules en place : C45**
# Voiles secondaires en Premurs**
# C40/50
# 55/30
# ** La classe de beton est indiquee dans le nom de chaque voile sur le plan
# *
# C
# A
# 15.12.22
# LEGENDE:
# DOCUMENTS DE REFERENCE :
# NOTES:
# MATERIAUX:
# - Les cotations sont données en mm
# - Les niveaux sont donnés en NVP
# - type de coupleur: voir fiche technique des coupleurs approuvee
# PREMIERE DIFFUSION
# KOT
# SVS
# TTR    DED EXE   ARM  PLA   SS1    362020
# 26.05.2023
# 1:50,1:20
# TTR-BED-EXE-STR-NDC-TSN-350000 -  Note: d'hypothèse générale structure
# T1
# : PREMIERE LIT SUPERIEUR
# T2
#             : DEUXIEME LIT SUPERIEUR
# B1
# : PREMIERE LIT INFERIEUR
# B2
# : DEUXIEME LIT INFERIEUR
# ADD'L
# : ADDITIONNEL
# SSL
#
# : NIVEAU STRUCTUREL DE LA DALLE
# LLB
# : LONGUE PARTIE INFERIEUR
# STG.
# : DECALE
# ALT
#             : ALTERNE
# ES
# : SUR CHAQUE COTE
# EF
# : SUR CHAQUE FACE
# EC                    : CHAQUE COIN
# H
# : HORIZONTAL
# V
# : VERTICAL
# TYP.
#
# : TYPIQUE
# Ep.
# : EPAISSEUR
# SF
#             : DE PROFIL
# OF
# : FACE EXTERIEURE
# IF
#             : FACE INTÉRIEURE
# CP.
#
# : COUPLEUR
# TH.
#             : FILETÉE
# TTR-BED-EXE-STR-PLA-SS2-380101    -   Plan de coffrage PLANCHER HAUT S1
# TTR-BED-EXE-STR-PLA-TSN-380510    -    Plancher haut S1 - Elevation poutres intérieures partie 1
# TTR-BED-EXE-STR-NDC-SS2-350140    -    NDC - Plancher haut SS2
# :"Poutres préfabriquées"
# Enrobage : Poutres = 70 mm ;
# Classe d'exposition : XC1
# Normes d exécution du béton armé :  NF EN 13670/cn
# Enrobage : poutres préfabriquées = 70 mm ;
# TTR-BED-EXE-STR-PLA-SS2-380102    -   Plan de coffrage PLANCHER HAUT E1
# TTR-BED-EXE-STR-PLA-TSN-380511   -    Plancher haut S1 - Elevation poutres intérieures partie 2
# B
# 14.01.23
# voir nuages & selon commentaires SETEC
# KOT
# SVS
# C
# 26.05.23
# Réponses aux commentaires
# KOT
# SVS
# 3A. EXTRACT TEXT OF
# SECTIONS CUTS  'ELE-'
# LOCATIONS.
# 3B  RETURN
# COORDINATES OF
# ASSOCIATED BOTTOM
# LINE OF THE RED
# HATCHED BOX
# 2a. EXTRACT TEXT OF GRID
# LOCATIONS (X1... Y1..)
# 2b . RETURN THE
# COORDINATES OF
# ASSOCIATED LINE (IN RED)
# OF EACH GRID
#
# 1.
# IDENTIFY TEXT
# AND RETURN
# COORDINATES OF
# DRAWING TITLES
# 4. RETURN DRAWING
# TITLE AND NUMBER

# %%
output=page.get_text("blocks")

# %%
output
# Out:
# [(65.99967956542969,
#   165.443359375,
#   78.11145782470703,
#   176.505859375,
#   'E1\n',
#   0,
#   0),
#  (40.439701080322266,
#   180.5633544921875,
#   94.1090316772461,
#   191.6258544921875,
#   '+30.86 NVP\n',
#   1,
#   0),
#  (282.9585266113281,
#   421.28955078125,
#   380.4663391113281,
#   434.9243469238281,
#   'P.S1.1.01 (600x 1030)\n',
#   2,
#   0),
#  (724.6763305664062,
#   432.0894775390625,
#   822.183837890625,
#   445.7242736816406,
#   'P.S1.1.02 (600x 1030)\n',
#   3,
#   0),
#  (1139.0343017578125,
#   166.7633056640625,
#   1151.1461181640625,
#   177.8258056640625,
#   'E1\n',
#   4,
#   0),
#  (1113.5943603515625,
#   181.88330078125,
#   1167.263916015625,
#   192.94580078125,
#   '+30.86 NVP\n',
#   5,
#   0),
#  (1393.43310546875,
#   388.40966796875,
#   1471.9759521484375,
#   402.0444641113281,
#   'P.S1.2 (600x 800)\n',
#   6,
#   0),
#  (1441.19287109375,
#   285.3302001953125,
#   1525.1541748046875,
#   298.9649963378906,
#   'P.S1.13 (700x 850)\n',
#   7,
#   0),
#  (1306.3135986328125,
#   66.6247329711914,
#   1320.78955078125,
#   81.16627502441406,
#   '10\n',
#   8,
#   0),
#  (1312.4498291015625,
#   84.62557220458984,
#   1315.3134765625,
#   94.2325668334961,
#   '-\n',
#   9,
#   0),
#  (1493.6326904296875,
#   72.5047378540039,
#   1500.8717041015625,
#   87.04627990722656,
#   '4\n',
#   10,
#   0),
#  (1018.794921875,
#   90.0632095336914,
#   1499.0162353515625,
#   109.36598205566406,
#   '-\n3\n',
#   11,
#   0),
#  (1021.3150024414062,
#   112.3831558227539,
#   1024.1785888671875,
#   121.99015045166016,
#   '-\n',
#   12,
#   0),
#  (83.51948547363281,
#   94.8244400024414,
#   90.75847625732422,
#   109.36598205566406,
#   '1\n',
#   13,
#   0),
#  (86.03958129882812,
#   112.3831558227539,
#   88.90320587158203,
#   121.99015045166016,
#   '-\n',
#   14,
#   0),
#  (507.8374328613281,
#   94.8244400024414,
#   515.076416015625,
#   109.36598205566406,
#   '2\n',
#   15,
#   0),
#  (510.3573913574219,
#   112.3831558227539,
#   513.2210083007812,
#   121.99015045166016,
#   '-\n',
#   16,
#   0),
#  (256.3187561035156,
#   88.3444595336914,
#   263.5577392578125,
#   102.88600158691406,
#   '8\n',
#   17,
#   0),
#  (258.735107421875,
#   106.22542572021484,
#   261.5987243652344,
#   115.8324203491211,
#   '-\n',
#   18,
#   0),
#  (731.1563110351562,
#   96.1445083618164,
#   738.3953247070312,
#   110.68605041503906,
#   '9\n',
#   19,
#   0),
#  (733.692626953125,
#   114.02547454833984,
#   736.5562744140625,
#   123.6324691772461,
#   '-\n',
#   20,
#   0),
#  (67.91956329345703,
#   576.441650390625,
#   80.03105163574219,
#   587.5038452148438,
#   'E1\n',
#   21,
#   0),
#  (42.35979461669922,
#   591.5615234375,
#   96.02781677246094,
#   602.6237182617188,
#   '+30.86 NVP\n',
#   22,
#   0),
#  (494.7574768066406,
#   791.6078491210938,
#   1028.68359375,
#   806.6824340820312,
#   'P.S1.1.07 (600x 800)\nP.S1.1.08 (600x 800)\n',
#   23,
#   0),
#  (116.15933227539062,
#   502.94268798828125,
#   123.398193359375,
#   517.4839477539062,
#   '5\n',
#   24,
#   0),
#  (118.6794204711914,
#   520.5011596679688,
#   121.54300689697266,
#   530.1080322265625,
#   '-\n',
#   25,
#   0),
#  (633.716796875,
#   506.06268310546875,
#   640.9556274414062,
#   520.6039428710938,
#   '6\n',
#   26,
#   0),
#  (636.23681640625,
#   523.6211547851562,
#   639.1004028320312,
#   533.22802734375,
#   '-\n',
#   27,
#   0),
#  (1138.1943359375,
#   495.86285400390625,
#   1145.4332275390625,
#   510.4041442871094,
#   '7\n',
#   28,
#   0),
#  (371.51806640625,
#   503.18280029296875,
#   1143.5777587890625,
#   523.028076171875,
#   '-\n11\n',
#   29,
#   0),
#  (377.6544494628906,
#   521.0634765625,
#   380.5180358886719,
#   530.6703491210938,
#   '-\n',
#   30,
#   0),
#  (975.9551391601562,
#   445.22296142578125,
#   990.4308471679688,
#   459.7642517089844,
#   '12\n',
#   31,
#   0),
#  (982.0914916992188,
#   463.1037292480469,
#   984.955078125,
#   472.7106018066406,
#   '-\n',
#   32,
#   0),
#  (188.39898681640625,
#   1051.165771484375,
#   280.4948425292969,
#   1064.801513671875,
#   'P.S1.1.01 (800x 600)\n',
#   33,
#   0),
#  (188.7589874267578,
#   1076.965576171875,
#   229.93565368652344,
#   1090.601318359375,
#   'V.S2.S01\n',
#   34,
#   0),
#  (461.39764404296875,
#   851.0065307617188,
#   507.97998046875,
#   878.8023071289062,
#   'C.S2.21\n(700x 700)\n',
#   35,
#   0),
#  (1192.9140625,
#   1059.085693359375,
#   1276.88134765625,
#   1072.721435546875,
#   'P.S1.13 (700x 850)\n',
#   36,
#   0),
#  (1193.994140625,
#   923.4862670898438,
#   1277.96142578125,
#   937.1220092773438,
#   'P.S1.13 (700x 850)\n',
#   37,
#   0),
#  (1586.51220703125,
#   1057.885498046875,
#   1678.6077880859375,
#   1071.521240234375,
#   'P.S1.10.2 (900x 850)\n',
#   38,
#   0),
#  (142.67919921875,
#   843.9266357421875,
#   183.8558807373047,
#   857.5623779296875,
#   'V.S1.S01\n',
#   39,
#   0),
#  (1838.15087890625,
#   1087.0455322265625,
#   1930.2464599609375,
#   1100.6812744140625,
#   'P.S1.1.07 (600x 800)\n',
#   40,
#   0),
#  (906.83544921875,
#   848.1265258789062,
#   953.4180297851562,
#   875.9223022460938,
#   'C.S2.22\n(700x 700)\n',
#   41,
#   0),
#  (1128.3543701171875,
#   1298.59814453125,
#   1140.465576171875,
#   1309.6600341796875,
#   'E1\n',
#   42,
#   0),
#  (1111.6744384765625,
#   1313.59814453125,
#   1163.6993408203125,
#   1324.6600341796875,
#   'SSL +30.86\n',
#   43,
#   0),
#  (137.39923095703125,
#   1212.80615234375,
#   767.4136962890625,
#   1245.76025390625,
#   'C.S2.26\n(900x 900)\nC.S2.27\n(900x 900)\n',
#   44,
#   0),
#  (321.47833251953125,
#   1419.3250732421875,
#   576.3158569335938,
#   1432.959228515625,
#   'P.S1.14 (700x 850)\nP.S1.13 (700x 850)\n',
#   45,
#   0),
#  (1388.753173828125,
#   1298.23828125,
#   1400.8643798828125,
#   1309.3001708984375,
#   'E1\n',
#   46,
#   0),
#  (1372.0732421875,
#   1313.3582763671875,
#   1424.0980224609375,
#   1324.420166015625,
#   'SSL +30.86\n',
#   47,
#   0),
#  (1893.83056640625,
#   210.68280029296875,
#   1905.9429931640625,
#   221.74583435058594,
#   'E1\n',
#   48,
#   0),
#  (1877.1507568359375,
#   225.68267822265625,
#   1929.180419921875,
#   236.74571228027344,
#   'SSL +30.86\n',
#   49,
#   0),
#  (1900.5506591796875,
#   544.7608032226562,
#   1912.6632080078125,
#   555.823974609375,
#   'E1\n',
#   50,
#   0),
#  (1883.870849609375,
#   559.8807983398438,
#   1935.9012451171875,
#   570.9439697265625,
#   'SSL +30.86\n',
#   51,
#   0),
#  (1721.631591796875,
#   540.8009643554688,
#   1733.744140625,
#   551.8641357421875,
#   'E1\n',
#   52,
#   0),
#  (1705.0716552734375,
#   555.8009643554688,
#   1757.10205078125,
#   566.8641357421875,
#   'SSL +30.89\n',
#   53,
#   0),
#  (1503.7125244140625,
#   536.3610229492188,
#   1515.8250732421875,
#   547.4241943359375,
#   'E1\n',
#   54,
#   0),
#  (1487.152587890625,
#   551.3609008789062,
#   1539.18310546875,
#   562.424072265625,
#   'SSL +30.86\n',
#   55,
#   0),
#  (1381.0732421875,
#   532.2809448242188,
#   1393.1856689453125,
#   543.3441162109375,
#   'E1\n',
#   56,
#   0),
#  (1364.5133056640625,
#   547.4008178710938,
#   1416.5438232421875,
#   558.4639892578125,
#   'SSL +30.89\n',
#   57,
#   0),
#  (2003.3983154296875,
#   1171.600341796875,
#   2169.958251953125,
#   1250.3203125,
#   '<image: DeviceRGB, width: 925, height: 437, bpc: 8>',
#   58,
#   1),
#  (2004.7100830078125,
#   1155.0037841796875,
#   2049.013427734375,
#   1159.642578125,
#   'PLAN DE REPERAGE :\n',
#   59,
#   0),
#  (2131.31982421875,
#   1165.4200439453125,
#   2142.76904296875,
#   1176.869140625,
#   'Nord\n',
#   60,
#   0),
#  (2023.1900634765625,
#   862.339111328125,
#   2298.979248046875,
#   896.7103881835938,
#   "Bonnes conditions - Tous les éléments sauf ferraillage supérieur des dalles et des poutres\n                                             d'épaisseur de plus de 25 cm\nBarre\nø (mm)\nDiamètre de Mandrin\n",
#   61,
#   0),
#  (2021.1500244140625,
#   897.8588256835938,
#   2114.929931640625,
#   914.4703369140625,
#   'C35/45\nAncrage (mm)\nRecouvrement (mm)\n',
#   62,
#   0),
#  (2021.1500244140625,
#   915.73876953125,
#   2114.929931640625,
#   932.350341796875,
#   'C45/55\nAncrage (mm)\nRecouvrement (mm)\n',
#   63,
#   0),
#  (2021.1500244140625,
#   933.498779296875,
#   2114.929931640625,
#   950.230224609375,
#   'C60/75\nAncrage (mm)\nRecouvrement (mm)\n',
#   64,
#   0),
#  (2021.1500244140625,
#   951.378662109375,
#   2114.929931640625,
#   967.9901123046875,
#   'C80/95\nAncrage (mm)\nRecouvrement (mm)\n',
#   65,
#   0),
#  (2126.029541015625,
#   880.0990600585938,
#   2137.57421875,
#   967.9901123046875,
#   '8\n32\n181\n271\n153\n229\n133\n200\n133\n200\n',
#   66,
#   0),
#  (2148.469482421875,
#   888.9788818359375,
#   2160.01416015625,
#   967.9901123046875,
#   '40\n226\n339\n191\n287\n166\n250\n166\n250\n',
#   67,
#   0),
#  (2170.78955078125,
#   888.9788818359375,
#   2182.333984375,
#   967.9901123046875,
#   '48\n300\n450\n254\n381\n221\n332\n221\n332\n',
#   68,
#   0),
#  (2215.669189453125,
#   888.9788818359375,
#   2227.213623046875,
#   967.9901123046875,
#   '64\n448\n673\n379\n569\n331\n496\n331\n496\n',
#   69,
#   0),
#  (2237.989013671875,
#   897.8588256835938,
#   2249.53369140625,
#   967.9901123046875,
#   '597\n895\n505\n757\n440\n660\n440\n660\n',
#   70,
#   0),
#  (2260.428955078125,
#   897.8588256835938,
#   2271.9736328125,
#   905.59033203125,
#   '782\n',
#   71,
#   0),
#  (2260.428955078125,
#   915.73876953125,
#   2271.9736328125,
#   967.9901123046875,
#   '662\n993\n577\n865\n577\n865\n',
#   72,
#   0),
#  (2282.86865234375,
#   915.73876953125,
#   2294.413330078125,
#   923.4702758789062,
#   '873\n',
#   73,
#   0),
#  (2282.86865234375,
#   933.498779296875,
#   2294.413330078125,
#   941.2302856445312,
#   '761\n',
#   74,
#   0),
#  (2282.86865234375,
#   951.378662109375,
#   2294.413330078125,
#   959.1101684570312,
#   '761\n',
#   75,
#   0),
#  (2150.389404296875,
#   880.0990600585938,
#   2292.485595703125,
#   896.7103881835938,
#   '10\n12\n16\n20\n25\n32\n140\n175\n',
#   76,
#   0),
#  (2258.509033203125,
#   906.7388305664062,
#   2273.901611328125,
#   914.4703369140625,
#   '1174\n',
#   77,
#   0),
#  (2280.94873046875,
#   888.9788818359375,
#   2296.34130859375,
#   914.4703369140625,
#   '224\n1032\n1549\n',
#   78,
#   0),
#  (2280.94873046875,
#   924.6188354492188,
#   2296.34130859375,
#   932.350341796875,
#   '1310\n',
#   79,
#   0),
#  (2280.94873046875,
#   942.4987182617188,
#   2296.34130859375,
#   950.230224609375,
#   '1142\n',
#   80,
#   0),
#  (2280.94873046875,
#   960.2586059570312,
#   2296.34130859375,
#   967.9901123046875,
#   '1142\n',
#   81,
#   0),
#  (2023.7900390625,
#   972.7384643554688,
#   2278.1015625,
#   1007.2299194335938,
#   "Mauvaises conditions -\nFerraillage supérieur des dalles et des poutres d'épaisseur de plus de 25 cm\nBarre\nø (mm)\nDiamètre de Mandrin\n",
#   82,
#   0),
#  (2021.1500244140625,
#   1008.4984130859375,
#   2114.929931640625,
#   1025.10986328125,
#   'C35/45\nAncrage (mm)\nRecouvrement (mm)\n',
#   83,
#   0),
#  (2021.1500244140625,
#   1026.25830078125,
#   2114.929931640625,
#   1042.98974609375,
#   'C45/55\nAncrage (mm)\nRecouvrement (mm)\n',
#   84,
#   0),
#  (2021.1500244140625,
#   1044.1383056640625,
#   2114.929931640625,
#   1060.749755859375,
#   'C60/75\nAncrage (mm)\nRecouvrement (mm)\n',
#   85,
#   0),
#  (2021.1500244140625,
#   1061.898193359375,
#   2114.929931640625,
#   1078.629638671875,
#   'C80/95\nAncrage (mm)\nRecouvrement (mm)\n',
#   86,
#   0),
#  (2126.029541015625,
#   990.6185302734375,
#   2137.57421875,
#   1060.749755859375,
#   '8\n32\n258\n387\n218\n327\n190\n285\n',
#   87,
#   0),
#  (2148.469482421875,
#   999.4984130859375,
#   2160.01416015625,
#   1060.749755859375,
#   '40\n323\n484\n273\n409\n238\n357\n',
#   88,
#   0),
#  (2170.78955078125,
#   999.4984130859375,
#   2182.333984375,
#   1060.749755859375,
#   '48\n429\n643\n363\n544\n316\n474\n',
#   89,
#   0),
#  (2215.669189453125,
#   999.4984130859375,
#   2227.213623046875,
#   1060.749755859375,
#   '64\n641\n961\n542\n813\n472\n708\n',
#   90,
#   0),
#  (2237.989013671875,
#   1008.4984130859375,
#   2249.53369140625,
#   1016.2299194335938,
#   '853\n',
#   91,
#   0),
#  (2237.989013671875,
#   1026.25830078125,
#   2249.53369140625,
#   1033.98974609375,
#   '721\n',
#   92,
#   0),
#  (2237.989013671875,
#   1044.1383056640625,
#   2249.53369140625,
#   1060.749755859375,
#   '629\n943\n',
#   93,
#   0),
#  (2260.428955078125,
#   1026.25830078125,
#   2271.9736328125,
#   1033.98974609375,
#   '945\n',
#   94,
#   0),
#  (2260.428955078125,
#   1044.1383056640625,
#   2271.9736328125,
#   1051.8697509765625,
#   '824\n',
#   95,
#   0),
#  (2150.389404296875,
#   990.6185302734375,
#   2292.485595703125,
#   1007.2299194335938,
#   '10\n12\n16\n20\n25\n32\n140\n175\n',
#   96,
#   0),
#  (2258.509033203125,
#   1017.3783569335938,
#   2273.901611328125,
#   1025.10986328125,
#   '1677\n',
#   97,
#   0),
#  (2280.94873046875,
#   999.4984130859375,
#   2296.34130859375,
#   1025.10986328125,
#   '224\n1475\n2212\n',
#   98,
#   0),
#  (2280.94873046875,
#   1035.25830078125,
#   2296.34130859375,
#   1042.98974609375,
#   '1871\n',
#   99,
#   0),
#  (2280.94873046875,
#   1053.018310546875,
#   2296.34130859375,
#   1060.749755859375,
#   '1631\n',
#   100,
#   0),
#  (2123.1494140625,
#   1082.05810546875,
#   2312.772216796875,
#   1089.78955078125,
#   '*Note : Ces valeurs sont à considérer sauf indication contraire\n',
#   101,
#   0),
#  (2236.06884765625,
#   1017.3783569335938,
#   2251.46142578125,
#   1025.10986328125,
#   '1279\n',
#   102,
#   0),
#  (2236.06884765625,
#   1035.25830078125,
#   2251.46142578125,
#   1042.98974609375,
#   '1082\n',
#   103,
#   0),
#  (2258.509033203125,
#   1008.4984130859375,
#   2273.901611328125,
#   1016.2299194335938,
#   '1118\n',
#   104,
#   0),
#  (2258.509033203125,
#   1035.25830078125,
#   2273.901611328125,
#   1042.98974609375,
#   '1418\n',
#   105,
#   0),
#  (2258.509033203125,
#   1053.018310546875,
#   2273.901611328125,
#   1060.749755859375,
#   '1236\n',
#   106,
#   0),
#  (2280.94873046875,
#   1026.25830078125,
#   2296.34130859375,
#   1033.98974609375,
#   '1247\n',
#   107,
#   0),
#  (2280.94873046875,
#   1044.1383056640625,
#   2296.34130859375,
#   1051.8697509765625,
#   '1087\n',
#   108,
#   0),
#  (2126.029541015625,
#   1061.898193359375,
#   2296.34130859375,
#   1078.629638671875,
#   '190\n285\n238\n357\n316\n474\n472\n708\n629\n943\n824\n1631\n1236\n1087\n',
#   109,
#   0),
#  (2193.229248046875,
#   888.9788818359375,
#   2204.77392578125,
#   967.9901123046875,
#   '56\n374\n561\n317\n475\n276\n414\n276\n414\n',
#   110,
#   0),
#  (2195.149169921875,
#   880.0990600585938,
#   2202.845947265625,
#   887.83056640625,
#   '14\n',
#   111,
#   0),
#  (2193.229248046875,
#   999.4984130859375,
#   2204.77392578125,
#   1060.749755859375,
#   '56\n535\n802\n452\n678\n394\n591\n',
#   112,
#   0),
#  (2195.149169921875,
#   990.6185302734375,
#   2202.845947265625,
#   998.3500366210938,
#   '14\n',
#   113,
#   0),
#  (2193.229248046875,
#   1061.898193359375,
#   2204.77392578125,
#   1078.629638671875,
#   '394\n591\n',
#   114,
#   0),
#  (2303.388671875,
#   915.73876953125,
#   2318.78125,
#   923.4702758789062,
#   '1186\n',
#   115,
#   0),
#  (2303.388671875,
#   933.498779296875,
#   2318.78125,
#   941.2302856445312,
#   '1034\n',
#   116,
#   0),
#  (2303.388671875,
#   880.0990600585938,
#   2318.78125,
#   914.4703369140625,
#   '40\n280\n1403\n2104\n',
#   117,
#   0),
#  (2303.388671875,
#   924.6188354492188,
#   2318.78125,
#   932.350341796875,
#   '1780\n',
#   118,
#   0),
#  (2303.388671875,
#   942.4987182617188,
#   2318.78125,
#   950.230224609375,
#   '1551\n',
#   119,
#   0),
#  (2303.388671875,
#   990.6185302734375,
#   2318.78125,
#   1025.10986328125,
#   '40\n280\n2004\n3006\n',
#   120,
#   0),
#  (2303.388671875,
#   1026.25830078125,
#   2318.78125,
#   1042.98974609375,
#   '2542\n1695\n',
#   121,
#   0),
#  (2303.388671875,
#   1061.898193359375,
#   2318.78125,
#   1078.629638671875,
#   '2216\n1477\n',
#   122,
#   0),
#  (2303.388671875,
#   951.378662109375,
#   2318.78125,
#   967.9901123046875,
#   '1034\n1551\n',
#   123,
#   0),
#  (2303.388671875,
#   1044.1383056640625,
#   2318.78125,
#   1060.749755859375,
#   '2216\n1477\n',
#   124,
#   0),
#  (2021.030029296875,
#   636.9743041992188,
#   2076.848388671875,
#   644.7130126953125,
#   'Elément structurel\n',
#   125,
#   0),
#  (2019.7099609375,
#   650.2942504882812,
#   2139.66259765625,
#   693.79150390625,
#   'Barrettes de fondation\nParoi moulée\nRadier\nContre voile**\nVoiles principaux du noyau(≥300mm)et\n',
#   126,
#   0),
#  (2020.4300537109375,
#   739.2138671875,
#   2132.458251953125,
#   833.2321166992188,
#   'Poteaux principaux de la tour\nPoteaux extérieurs\nPoutres\nPlanchers béton\nChape de compression des DAP\nEscalier préfabriqué\nRampe accès parking et sa toiture\naccessible aux pompier\nDalles et poutres des terrasses sous\nétanchéité\nRadier et toiture du Carneau\n',
#   127,
#   0),
#  (2155.189453125,
#   633.1344604492188,
#   2185.9873046875,
#   684.7929077148438,
#   'Classe de\n   béton\nC40/50\nC40/50\nC45/55\nC45/55\n',
#   128,
#   0),
#  (2159.509521484375,
#   693.6141357421875,
#   2181.8427734375,
#   701.3528442382812,
#   'C60/75\n',
#   129,
#   0),
#  (2159.509521484375,
#   717.1339721679688,
#   2181.8427734375,
#   724.8726806640625,
#   'C45/55\n',
#   130,
#   0),
#  (2159.509521484375,
#   739.2138671875,
#   2181.8427734375,
#   791.59228515625,
#   'C80/95\nC80/95\nC35/45\nC35/45\nC35/45\nC35/45\n',
#   131,
#   0),
#  (2159.509521484375,
#   796.45361328125,
#   2181.8427734375,
#   804.1923217773438,
#   'C45/55\n',
#   132,
#   0),
#  (2159.509521484375,
#   812.1735229492188,
#   2181.8427734375,
#   819.9122314453125,
#   'C35/45\n',
#   133,
#   0),
#  (2159.509521484375,
#   825.493408203125,
#   2181.8427734375,
#   833.2321166992188,
#   'C35/45\n',
#   134,
#   0),
#  (2203.9091796875,
#   633.2544555664062,
#   2233.945068359375,
#   684.7929077148438,
#   'Enrobage\n     mm\n75\n75\n50\n55\n',
#   135,
#   0),
#  (2210.38916015625,
#   693.6141357421875,
#   2227.72119140625,
#   701.3528442382812,
#   '55/30\n',
#   136,
#   0),
#  (2210.38916015625,
#   717.1339721679688,
#   2227.72119140625,
#   724.8726806640625,
#   '55/30\n',
#   137,
#   0),
#  (2215.189208984375,
#   739.2138671875,
#   2222.89306640625,
#   755.83251953125,
#   '60\n60\n',
#   138,
#   0),
#  (2215.189208984375,
#   765.9495849609375,
#   2222.89306640625,
#   791.59228515625,
#   '*\n20\n35\n',
#   139,
#   0),
#  (2215.189208984375,
#   796.45361328125,
#   2222.89306640625,
#   804.1923217773438,
#   '35\n',
#   140,
#   0),
#  (2215.189208984375,
#   812.1735229492188,
#   2222.89306640625,
#   819.9122314453125,
#   '35\n',
#   141,
#   0),
#  (2215.189208984375,
#   825.493408203125,
#   2222.89306640625,
#   833.2321166992188,
#   '35\n',
#   142,
#   0),
#  (2020.31005859375,
#   845.4132690429688,
#   2145.993408203125,
#   853.1519775390625,
#   "* Selon l'étage. Voir indication sur le plan\n",
#   143,
#   0),
#  (2021.030029296875,
#   833.8934326171875,
#   2222.89306640625,
#   842.1121215820312,
#   'rampe voiture intérieure\n35\nC35/45 \n',
#   144,
#   0),
#  (2019.7099609375,
#   693.4940795898438,
#   2125.573974609375,
#   708.4327392578125,
#   'ascenseur panoramique y compris\nlinteaux: C60**\n',
#   145,
#   0),
#  (2019.7099609375,
#   712.2139892578125,
#   2145.792236328125,
#   727.5126953125,
#   'Voiles secondaires du noyau(<300mm)et\nAutres voiles coules en place : C45**\n',
#   146,
#   0),
#  (2021.030029296875,
#   730.3339233398438,
#   2227.72119140625,
#   738.192626953125,
#   'Voiles secondaires en Premurs**\nC40/50\n55/30\n',
#   147,
#   0),
#  (2020.31005859375,
#   854.0533447265625,
#   2249.0234375,
#   861.7920532226562,
#   '** La classe de beton est indiquee dans le nom de chaque voile sur le plan\n',
#   148,
#   0),
#  (2216.869140625,
#   757.069580078125,
#   2221.22607421875,
#   769.5770263671875,
#   '*\n',
#   149,
#   0),
#  (2333.868408203125,
#   1632.9288330078125,
#   2340.897216796875,
#   1646.55712890625,
#   'C\n',
#   150,
#   0),
#  (2006.750244140625,
#   1329.371826171875,
#   2044.267822265625,
#   1335.74853515625,
#   'A\n15.12.22\n',
#   151,
#   0),
#  (2008.5501708984375,
#   213.44747924804688,
#   2058.599609375,
#   224.50474548339844,
#   'LEGENDE:\n',
#   152,
#   0),
#  (2003.510009765625,
#   1100.1673583984375,
#   2077.09716796875,
#   1106.9813232421875,
#   'DOCUMENTS DE REFERENCE :\n',
#   153,
#   0),
#  (2003.990234375,
#   34.13804244995117,
#   2041.4541015625,
#   45.380592346191406,
#   'NOTES:\n',
#   154,
#   0),
#  (2009.150146484375,
#   141.05760192871094,
#   2070.655029296875,
#   152.30015563964844,
#   'MATERIAUX:\n',
#   155,
#   0),
#  (2013.22998046875,
#   51.77805709838867,
#   2301.857421875,
#   87.2603530883789,
#   '- Les cotations sont données en mm\n- Les niveaux sont donnés en NVP\n- type de coupleur: voir fiche technique des coupleurs approuvee\n',
#   156,
#   0),
#  (2152.78955078125,
#   1329.371826171875,
#   2347.475341796875,
#   1335.6285400390625,
#   'PREMIERE DIFFUSION\nKOT\nSVS\n',
#   157,
#   0),
#  (2145.469482421875,
#   1636.3155517578125,
#   2314.491455078125,
#   1645.700439453125,
#   'TTR    DED EXE   ARM  PLA   SS1    362020\n',
#   158,
#   0),
#  (2054.6298828125,
#   1629.370361328125,
#   2082.654541015625,
#   1635.6270751953125,
#   '26.05.2023\n',
#   159,
#   0),
#  (2023.070068359375,
#   1643.4102783203125,
#   2046.4248046875,
#   1649.6669921875,
#   '1:50,1:20\n',
#   160,
#   0),
#  (2005.3101806640625,
#   1106.894287109375,
#   2204.835205078125,
#   1114.132568359375,
#   "TTR-BED-EXE-STR-NDC-TSN-350000 -  Note: d'hypothèse générale structure\n",
#   161,
#   0),
#  (2015.7501220703125,
#   230.30763244628906,
#   2217.613037109375,
#   483.4632568359375,
#   "T1         \n: PREMIERE LIT SUPERIEUR\nT2\n            : DEUXIEME LIT SUPERIEUR\nB1 \n: PREMIERE LIT INFERIEUR\nB2\n: DEUXIEME LIT INFERIEUR\nADD'L      \n: ADDITIONNEL\nSSL\n \n: NIVEAU STRUCTUREL DE LA DALLE\nLLB\n: LONGUE PARTIE INFERIEUR\nSTG.\n: DECALE\nALT\n            : ALTERNE\nES\n: SUR CHAQUE COTE\nEF \n: SUR CHAQUE FACE\nEC                    : CHAQUE COIN\nH\n: HORIZONTAL\nV\n: VERTICAL\nTYP.\n \n: TYPIQUE\nEp.        \n: EPAISSEUR\nSF  \n            : DE PROFIL\nOF        \n: FACE EXTERIEURE\nIF  \n            : FACE INTÉRIEURE\nCP.\n       \n: COUPLEUR\nTH.\n            : FILETÉE\n",
#   162,
#   0),
#  (2005.3101806640625,
#   1113.01416015625,
#   2205.573486328125,
#   1120.25244140625,
#   'TTR-BED-EXE-STR-PLA-SS2-380101    -   Plan de coffrage PLANCHER HAUT S1\n',
#   163,
#   0),
#  (2005.3101806640625,
#   1125.6917724609375,
#   2259.3720703125,
#   1134.05224609375,
#   'TTR-BED-EXE-STR-PLA-TSN-380510    -    Plancher haut S1 - Elevation poutres intérieures partie 1\n',
#   164,
#   0),
#  (2005.3101806640625,
#   1141.2918701171875,
#   2176.942626953125,
#   1149.65234375,
#   'TTR-BED-EXE-STR-NDC-SS2-350140    -    NDC - Plancher haut SS2\n',
#   165,
#   0),
#  (2231.26904296875,
#   407.3067932128906,
#   2319.13720703125,
#   418.6636962890625,
#   ':"Poutres préfabriquées"\n',
#   166,
#   0),
#  (2027.5098876953125,
#   154.46803283691406,
#   2136.0146484375,
#   178.30479431152344,
#   "Enrobage : Poutres = 70 mm ;\nClasse d'exposition : XC1\n",
#   167,
#   0),
#  (2027.5098876953125,
#   178.46791076660156,
#   2223.29931640625,
#   201.10459899902344,
#   'Normes d exécution du béton armé :  NF EN 13670/cn\nEnrobage : poutres préfabriquées = 70 mm ;\n',
#   168,
#   0),
#  (2005.3101806640625,
#   1119.8541259765625,
#   2205.76220703125,
#   1127.0924072265625,
#   'TTR-BED-EXE-STR-PLA-SS2-380102    -   Plan de coffrage PLANCHER HAUT E1\n',
#   169,
#   0),
#  (2005.3101806640625,
#   1133.2518310546875,
#   2257.931884765625,
#   1141.6123046875,
#   'TTR-BED-EXE-STR-PLA-TSN-380511   -    Plancher haut S1 - Elevation poutres intérieures partie 2\n',
#   170,
#   0),
#  (2006.750244140625,
#   1314.251953125,
#   2347.475341796875,
#   1328.1884765625,
#   'B\n14.01.23\nvoir nuages & selon commentaires SETEC\nKOT\nSVS\nC\n26.05.23\nRéponses aux commentaires\nKOT\nSVS\n',
#   171,
#   0),
#  (1782.5670166015625,
#   1215.156982421875,
#   1886.7568359375,
#   1318.55712890625,
#   "3A. EXTRACT TEXT OF \nSECTIONS CUTS  'ELE-' \nLOCATIONS. \n3B  RETURN \nCOORDINATES OF \nASSOCIATED BOTTOM \nLINE OF THE RED \nHATCHED BOX  \n",
#   172,
#   0),
#  (1578.9510498046875,
#   1232.1500244140625,
#   1704.1978759765625,
#   1322.35009765625,
#   '2a. EXTRACT TEXT OF GRID \nLOCATIONS (X1... Y1..) \n2b . RETURN THE \nCOORDINATES OF \nASSOCIATED LINE (IN RED) \nOF EACH GRID \n \n',
#   173,
#   0),
#  (728.450927734375,
#   304.5799560546875,
#   833.36474609375,
#   355.1800537109375,
#   '1. \nIDENTIFY TEXT \nAND RETURN \nCOORDINATES OF \nDRAWING TITLES\n',
#   174,
#   0),
#  (2159.199951171875,
#   1485.423828125,
#   2257.26708984375,
#   1509.8515625,
#   '4. RETURN DRAWING\nTITLE AND NUMBER\n',
#   175,
#   0)]
